# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, plot_confusion_matrix
import numpy as np

# %%
# Reading the file
df = pd.read_csv("heartDataSet.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# - maybe adding a little description about the columns
# - the meaning of target, what does 0 and 1 stand for

# %% [markdown]
# ## Assumptions:
# - The data is cleaned, so we don't need to do data manipulation to clean it

# %% [markdown]
# ### Default (without pruning)

# %%
# split the dataset to 'Features' and 'target'
X = df.drop("target", axis=1)
y = df["target"]
print(X.shape, y.shape)
# Out:
# (303, 13) (303,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=22)

# %%
clf_dt = DecisionTreeClassifier(random_state=22)
clf_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=22)

# %%
# The size of the figure
plt.figure(figsize=(15, 8))
# plt.style.use("seaborn-dark")
# '0' in the target represent not having HD, while '1' represent having HD
plot_tree(clf_dt, feature_names=X.columns, class_names=["Not have HD", "Have HD"], filled=True)
plt.show()

# %%
# Metrics
dt_prediction = clf_dt.predict(X_test)
accuracy = accuracy_score(y_test, dt_prediction)
precision = precision_score(y_test, dt_prediction)
recall = recall_score(y_test, dt_prediction)
print(accuracy, precision, recall)
# Out:
# 0.6813186813186813 0.660377358490566 0.7608695652173914

# %%
plot_confusion_matrix(clf_dt, X_test, y_test, display_labels=["Not have HD", "Have HD"])
plt.show()

# %% [markdown]
# - maybe adding a little describtion or explnation about the different of `accuracy`, `precision`, and `recall`

# %% [markdown]
# ### Cost Complexity Path (Pruning)
# [sklearn documentation for information](https://scikit-learn.org/stable/auto_examples/tree/plot_cost_complexity_pruning.html)

# %%
ccp_alphas = clf_dt.cost_complexity_pruning_path(X_train, y_train)["ccp_alphas"] # list of possible alphas
ccp_alphas
# Out:
# array([0.        , 0.00314465, 0.00393082, 0.00424528, 0.00460978,
#        0.00503145, 0.00561545, 0.00566038, 0.00575022, 0.00607244,
#        0.00679369, 0.00707547, 0.00707547, 0.00786164, 0.0093727 ,
#        0.01179245, 0.0135894 , 0.01558655, 0.02518709, 0.0396007 ,
#        0.04928683, 0.14593511])

# %%
# find the best ccp alpha that maximize the accuracy
train_scores = []
test_scores = []

for alpha in ccp_alphas:
    clf_dt = DecisionTreeClassifier(random_state=22, ccp_alpha=alpha)
    clf_dt.fit(X_train, y_train)
    train_scores.append(clf_dt.score(X_train, y_train)) # append the 'accuracy' score of training set
    test_scores.append(clf_dt.score(X_test, y_test))

# %%
plt.style.use("seaborn")

# %%
plt.figure(figsize=(12, 8))
plt.plot(ccp_alphas, train_scores, label="training score", drawstyle="steps-post", marker="o")
plt.plot(ccp_alphas, test_scores, label="testing score", drawstyle="steps-post", marker="o")
plt.xlabel("alpha")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.plot(ccp_alphas, train_scores, label="training score", drawstyle="steps-post", marker="o")
plt.plot(ccp_alphas, test_scores, label="testing score", drawstyle="steps-post", marker="o")
plt.xlabel("alpha")
plt.ylabel("accuracy")
plt.legend()
plt.xticks([0.00, 0.01, 0.015, 0.02, 0.025])
plt.xlim([0.00, 0.025])
plt.show()

# %%
best_alpha = 0.016
clf_dt = DecisionTreeClassifier(random_state=22, ccp_alpha=best_alpha)
clf_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.016, random_state=22)

# %%
# Metrics
dt_prediction = clf_dt.predict(X_test)
accuracy = accuracy_score(y_test, dt_prediction)
precision = precision_score(y_test, dt_prediction)
recall = recall_score(y_test, dt_prediction)
print(accuracy, precision, recall)
# Out:
# 0.7912087912087912 0.7454545454545455 0.8913043478260869

# %%
plt.figure()
plot_confusion_matrix(clf_dt, X_test, y_test, display_labels=["Not have HD", "Have HD"])
plt.show()

# %%
# The size of the figure
plt.figure(figsize=(15, 8))
# plt.style.use("seaborn-dark")
# '0' in the target represent not having HD, while '1' represent having HD
plot_tree(clf_dt, feature_names=X.columns, class_names=["Not have HD", "Have HD"], filled=True)
plt.show()

# %% [markdown]
# ### Cross Validation
# Optimaiztion to find the best training set with ccp

# %%
clf_dt = DecisionTreeClassifier(random_state=22, ccp_alpha=best_alpha)

scores = cross_val_score(clf_dt, X_train, y_train, scoring="accuracy", cv=5)
plt.plot(np.array(range(5)), scores)
plt.xlabel("K-Fold")
plt.ylabel("Accuracy")
plt.title("Performance of current alpha with different training set")
plt.show()

# %%
scores
# Out:
# array([0.79069767, 0.74418605, 0.80952381, 0.80952381, 0.76190476])

# %%
alphas_list = []
for alpha in ccp_alphas:
    clf_dt = DecisionTreeClassifier(random_state=22, ccp_alpha=alpha)
    scores = cross_val_score(clf_dt, X_train, y_train, scoring="accuracy", cv=5)
    alphas_list.append([alpha, np.mean(scores)])

alphas_df = pd.DataFrame(alphas_list, columns=["Alpha", "Mean"])
alphas_df.sort_values("Mean", ascending=False).head()
# Out:
#        Alpha      Mean
# 15  0.011792  0.811628
# 16  0.013589  0.806977
# 14  0.009373  0.792802
# 6   0.005615  0.788040
# 7   0.005660  0.788040

# %%
# alphas_df.nlargest(1, "Mean")
# extract the best alpha from the dataframe
# Out:
#        Alpha      Mean
# 15  0.011792  0.811628
